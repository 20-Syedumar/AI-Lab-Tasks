# %%
#Mini Project 2:
movies = [
("Eternal Sunshine of the Spotless Mind", 20000000),
("Memento", 9000000),
("Requiem for a Dream", 4500000),
("Pirates of the Caribbean: On Stranger Tides", 379000000),
("Avengers: Age of Ultron", 365000000),
("Avengers: Endgame", 356000000),
("Incredibles 2", 200000000)
]

def add_movie():
    num = int(input("enter the number of movies you want to enter: "))
    for i in range(num):
        movie = input("enter the name of the movie: ")
        budget = int(input("enter the budget of the movie: "))
        movies.append((movie, budget))
        print(f"Movie {movie} with budget {budget}$ added successfully!")

add_movie()   

total = 0 
for movie, budget in movies:
     total += budget 
     average = total/ len(movies)
print(f"total: {total}$, average: {average}$")
count = 0
for movie, budget in movies:
     if budget > average:
        difference = budget - average 
        count += 1
        print(f"{movie} above average budget by {difference}$")
print(f"total number of movies above budget: {count}")
# Out:
# Movie 'Tin Tin' with budget 2000000$ added successfully!
# total: 1335500000$, average: 166937500.0$
#
#
# Pirates of the Caribbean: On Stranger Tides above average budget by 212062500.0$
# Avengers: Age of Ultron above average budget by 198062500.0$
# Avengers: Endgame above average budget by 189062500.0$
# Incredibles 2 above average budget by 33062500.0$
# total number of movies above budget: 4

# %%
#Mini Project 1:
def fizz_buzz():
    for num in range(1, 101):
        if num % 3 == 0 and num % 5 == 0:
            print("Fizz Buzz")
        elif num % 3 == 0:
            print("Fizz")
        elif num % 5 == 0:
            print("Buzz")
        else:
            print(num) 
fizz_buzz()
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz Buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz Buzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz Buzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz Buzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz Buzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz Buzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
